# %% [markdown]
# # Bharat Bazaar Intelligence Platform
#
# # Interactive Business Dashboard
#
# ## Project Objective
#
# This notebook presents an interactive business dashboard built using Python.
#
# The dashboard summarizes:
#
# - Overall Business Performance
# - Sales Analytics
# - Profit Analytics
# - Regional Performance
# - Customer Segments
# - Product Categories
# - Payment Methods
#
# The objective is to provide business stakeholders with a quick overview of key performance indicators (KPIs) and actionable insights for data-driven decision making.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# Load Dataset
df = pd.read_csv("../data/cleaned/cleaned_global_ecommerce_sales.csv")

print("Dataset Shape :", df.shape)

df.head()
# Out:
# Dataset Shape : (2000, 15)
#     Order_ID  Order_Date   Customer_Name Customer_Segment        Country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11454  2023-01-05    Felix Thomas         Consumer          Italy
#
#           Region Product_Category                   Product_Name  Quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4         Europe        Furniture        Standing Desk Converter         4
#
# ...

# %% [markdown]
# # Dashboard KPIs
#
# The following KPIs summarize the overall business performance.

# %%
total_sales = df["Total_Sales"].sum()
total_profit = df["Profit"].sum()
total_orders = df["Order_ID"].nunique()
total_customers = df["Customer_Name"].nunique()

print("="*60)
print("BUSINESS DASHBOARD")
print("="*60)

print(f"Total Sales      : ${total_sales:,.2f}")
print(f"Total Profit     : ${total_profit:,.2f}")
print(f"Total Orders     : {total_orders}")
print(f"Total Customers  : {total_customers}")
# Out:
# ...
# BUSINESS DASHBOARD
# ...
# Total Sales      : $484,559.34
# Total Profit     : $158,872.32
# Total Orders     : 2000
# Total Customers  : 1534

# %% [markdown]
# # Sales by Region
#
# This visualization highlights regional sales performance.

# %%
region_sales = (
    df.groupby("Region")["Total_Sales"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))

region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.ylabel("Total Sales")
plt.xlabel("Region")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# # Customer Segment Dashboard
#
# ## Objective
#
# This section visualizes sales generated by different customer segments.
#
# It helps identify:
#
# - High-value customer groups
# - Revenue contribution by each segment
# - Business opportunities for targeted marketing

# %%
segment_sales = (
    df.groupby("Customer_Segment")["Total_Sales"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))

segment_sales.plot(kind="bar")

plt.title("Sales by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Sales")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# # Product Category Dashboard
#
# This dashboard compares total sales across product categories.

# %%
category_sales = (
    df.groupby("Product_Category")["Total_Sales"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))

category_sales.plot(kind="bar")

plt.title("Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# # Payment Method Dashboard
#
# This chart shows customer preferences for payment methods.

# %%
payment_counts = df["Payment_Method"].value_counts()

plt.figure(figsize=(8,5))

payment_counts.plot(kind="bar")

plt.title("Orders by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Orders")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# # Monthly Sales Trend
#
# This section analyzes how total sales change over time.

# %%
# Convert Order_Date to datetime
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

monthly_sales = (
    df.groupby(df["Order_Date"].dt.to_period("M"))["Total_Sales"]
      .sum()
)

monthly_sales.index = monthly_sales.index.astype(str)

plt.figure(figsize=(12,6))

plt.plot(monthly_sales.index, monthly_sales.values, marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# # Top 10 Best-Selling Products Dashboard
#
# ## Objective
#
# This dashboard identifies the top 10 products contributing the highest sales revenue.
#
# The insights help businesses:
#
# - Prioritize inventory planning.
# - Improve marketing strategies.
# - Focus on high-performing products.

# %%
top_products = (
    df.groupby("Product_Name")["Total_Sales"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

plt.figure(figsize=(12,6))

top_products.plot(kind="bar")

plt.title("Top 10 Products by Sales")
plt.xlabel("Product Name")
plt.ylabel("Total Sales")

plt.xticks(rotation=45, ha="right")

plt.grid(axis="y", alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# # Profit Dashboard
#
# ## Objective
#
# This section analyzes the profitability generated across product categories.
#
# Profit analysis helps identify which categories contribute most to business growth.

# %%
category_profit = (
    df.groupby("Product_Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(10,6))

category_profit.plot(kind="bar")

plt.title("Profit by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Profit")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# # Executive Summary
#
# ## Key Dashboard Highlights
#
# - Total sales and profit provide an overview of business performance.
# - Regional analysis identifies high-performing markets.
# - Customer segment analysis highlights valuable customer groups.
# - Product category analysis supports inventory planning.
# - Payment method analysis improves customer experience.
# - Monthly sales trends help monitor business growth.
# - Top-selling products guide marketing and stocking decisions.
#
# These dashboards provide business leaders with actionable insights for strategic decision-making.

# %% [markdown]
# # Final Conclusion
#
# The Bharat Bazaar Intelligence Platform dashboard successfully transforms raw e-commerce data into meaningful business insights.
#
# Using Python-based analytics and visualizations, the dashboard enables stakeholders to monitor key performance indicators, evaluate regional and customer trends, identify top-performing products, and support data-driven business decisions.
#
# This project demonstrates practical skills in:
#
# - Data Cleaning
# - Exploratory Data Analysis
# - Feature Engineering
# - Machine Learning
# - Business Intelligence
# - Dashboard Development
# - Data Visualization
#
# Overall, the project showcases an end-to-end Data Analytics workflow suitable for real-world business applications.

# %% [markdown]
# # Bharat Bazaar Intelligence Platform (BBIP)
#
# ## AI-Powered Business Intelligence Platform for Indian Retailers
#
# ### Developed By
# Jaspreet Kaur
#
# ### Project Type
# End-to-End Data Analytics & Business Intelligence Project

# %% [markdown]
# # Project Overview
#
# The Bharat Bazaar Intelligence Platform (BBIP) is an end-to-end Data Analytics and Business Intelligence project developed to analyze retail sales data and transform raw business transactions into meaningful insights.
#
# The project follows the complete analytics lifecycle, including data understanding, data cleaning, SQL analysis, exploratory data analysis (EDA), machine learning, dashboard development, and deployment.

# %% [markdown]
# # Business Problem
#
# Retail businesses generate large volumes of transactional data every day. Without proper analysis, this data cannot effectively support strategic business decisions.
#
# This project aims to convert raw retail data into actionable insights that help business owners improve sales performance, understand customer behavior, optimize inventory, and increase profitability.

# %% [markdown]
# # Project Objectives
#
# The primary objectives of this project are:
#
# - Understand the retail dataset.
# - Assess overall data quality.
# - Identify important business metrics.
# - Prepare the dataset for advanced analytics.
# - Build business intelligence dashboards.
# - Develop predictive machine learning models.
# - Support data-driven business decision making.

# %% [markdown]
# # Expected Business Outcomes
#
# After completing this project, business stakeholders will be able to:
#
# - Monitor sales performance.
# - Analyze profit trends.
# - Identify top-performing products.
# - Understand customer purchasing behavior.
# - Compare regional performance.
# - Improve inventory planning.
# - Support strategic business decisions using data.

# %% [markdown]
# # Environment Setup
#
# Before starting the analysis, we import the required Python libraries. These libraries help us load, manipulate, and analyze the dataset efficiently.

# %%
# Import required libraries

import pandas as pd
import numpy as np

# %% [markdown]
# # Load Dataset
#
# The raw retail dataset is loaded into a Pandas DataFrame for further exploration and analysis.

# %%
# Load the dataset

df = pd.read_csv("../data/raw/global_ecommerce_sales.csv")

# %% [markdown]
# # Verify Dataset Loading
#
# Before performing any analysis, we verify that the dataset has been loaded successfully.

# %%
# Display the first five rows

df.head()
# Out:
#     Order_ID  Order_Date   Customer_Name Customer_Segment        Country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11454  2023-01-05    Felix Thomas         Consumer          Italy
#
#           Region Product_Category                   Product_Name  Quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4         Europe        Furniture        Standing Desk Converter         4
#
#    Unit_Price  Discount_Percent  Total_Sales  Shipping_Cost  Profit  \
# ...

# %% [markdown]
# # Business Observation
#
# The dataset has been successfully loaded into the DataFrame. The first five records confirm that each row represents a retail transaction containing customer details, product information, sales, profit, shipping cost, and payment method. The dataset structure appears suitable for further business analysis.

# %% [markdown]
# # Dataset Profiling
#
# Dataset profiling helps us understand the overall structure, size, and characteristics of the data before performing detailed analysis.

# %%
# Display dataset dimensions

print(f"Number of Rows    : {df.shape[0]}")
print(f"Number of Columns : {df.shape[1]}")
# Out:
# Number of Rows    : 2000
# Number of Columns : 15

# %% [markdown]
# # Business Observation
#
# The dataset contains retail transaction records with multiple business attributes. Understanding the size of the dataset helps estimate the scope of analysis and computational requirements.

# %%
# Display column names

df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Name', 'Customer_Segment',
#        'Country', 'Region', 'Product_Category', 'Product_Name', 'Quantity',
#        'Unit_Price', 'Discount_Percent', 'Total_Sales', 'Shipping_Cost',
#        'Profit', 'Payment_Method'],
#       dtype='str')

# %% [markdown]
# # Business Observation
#
# The dataset includes customer, product, sales, profit, shipping, payment, and regional information. These features provide a strong foundation for business intelligence and predictive analytics.

# %%
# Display data types

df.dtypes
# Out:
# Order_ID                str
# Order_Date              str
# Customer_Name           str
# Customer_Segment        str
# Country                 str
# Region                  str
# Product_Category        str
# Product_Name            str
# Quantity              int64
# Unit_Price          float64
# Discount_Percent      int64
# Total_Sales         float64
# Shipping_Cost       float64
# Profit              float64
# Payment_Method          str
# dtype: object

# %% [markdown]
# # Business Observation
#
# The dataset contains both numerical and categorical features. This combination supports descriptive analytics, SQL reporting, machine learning, and dashboard development.

# %%
# Display dataset information

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2000 non-null   str
#  1   Order_Date        2000 non-null   str
#  2   Customer_Name     2000 non-null   str
#  3   Customer_Segment  2000 non-null   str
#  4   Country           2000 non-null   str
#  5   Region            2000 non-null   str
#  6   Product_Category  2000 non-null   str
#  7   Product_Name      2000 non-null   str
#  8   Quantity          2000 non-null   int64
#  9   Unit_Price        2000 non-null   float64
#  10  Discount_Percent  2000 non-null   int64
#  11  Total_Sales       2000 non-null   float64
#  12  Shipping_Cost     2000 non-null   float64
#  13  Profit            2000 non-null   float64
#  14  Payment_Method    2000 non-null   str
# dtypes: float64(4), int64(2), str(9)
# memory usage: 440.1 KB

# %% [markdown]
# # Business Observation
#
# The dataset structure confirms that the records are well-organized and suitable for further quality assessment and business analysis.

# %% [markdown]
# # Data Quality Assessment
#
# Before performing any business analysis, it is important to evaluate the quality of the dataset. High-quality data leads to accurate insights and reliable business decisions.

# %%
# Check missing values

df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Name       0
# Customer_Segment    0
# Country             0
# Region              0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Total_Sales         0
# Shipping_Cost       0
# Profit              0
# Payment_Method      0
# dtype: int64

# %% [markdown]
# # Business Observation
#
# Missing values can affect data quality and model performance. This analysis helps identify whether data cleaning is required before further analysis.

# %%
# Check duplicate records

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Business Observation
#
# Duplicate records can lead to inaccurate sales, profit, and customer metrics. Identifying duplicates is an essential step in ensuring data reliability.

# %%
# Display statistical summary for numerical columns

df.describe()
# Out:
#           Quantity   Unit_Price  Discount_Percent  Total_Sales  Shipping_Cost  \
# count  2000.000000  2000.000000       2000.000000  2000.000000     2000.00000
# mean      3.557500    73.329490          8.572500   242.279670       12.90212
# std       2.704506    79.311014          7.261274   382.583802        5.22319
# min       1.000000     3.030000          0.000000     2.420000        5.52000
# 25%       2.000000    18.757500          0.000000    41.227500        9.45750
# 50%       3.000000    46.420000         10.000000   113.125000       11.84500
# 75%       5.000000    90.250000         15.000000   266.552500       14.92000
# max      15.000000   472.560000         30.000000  3813.980000       40.44000
#
#             Profit
# count  2000.000000
# mean     79.436160
# std     137.573593
# min     -11.280000
# 25%       6.865000
# 50%      32.830000
# 75%      90.297500
# max    1373.630000

# %% [markdown]
# # Business Observation
#
# The statistical summary provides information about the distribution of numerical variables such as sales, profit, quantity, shipping cost, and unit price. These metrics help identify unusual values and understand business performance.

# %%
# Display statistical summary for categorical columns

df.describe(include="object")
# Out:
# C:\Users\Loq\AppData\Local\Temp\ipykernel_25336\4165589149.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#          Order_ID  Order_Date Customer_Name Customer_Segment Country  \
# count        2000        2000          2000             2000    2000
# unique       2000         907          1534                3      20
# top     ORD-11121  2023-12-11    Chen Patel         Consumer  Mexico
# freq            1           8             5             1006     203
#
#                Region Product_Category              Product_Name  \
# ...

# %% [markdown]
# # Business Observation
#
# The categorical summary provides insights into customer names, product categories, payment methods, and regional information. It helps understand the diversity and frequency of business attributes.

# %%
# Check memory usage

df.memory_usage(deep=True)
# Out:
# Index                 132
# Order_ID            34000
# Order_Date          36000
# Customer_Name       40227
# Customer_Segment    33736
# Country             31467
# Region              39415
# Product_Category    43014
# Product_Name        59577
# Quantity            16000
# Unit_Price          16000
# Discount_Percent    16000
# Total_Sales         16000
# Shipping_Cost       16000
# Profit              16000
# Payment_Method      37046
# dtype: int64

# %% [markdown]
# # Business Observation
#
# Memory usage analysis helps evaluate the efficiency of the dataset. This information becomes valuable when working with larger datasets and optimizing data processing workflows.

# %% [markdown]
# # Feature Understanding
#
# Understanding each feature is essential before performing business analysis. The following table describes the purpose and business importance of every column in the dataset.

# %%
# Display all column names

df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Name',
#  'Customer_Segment',
#  'Country',
#  'Region',
#  'Product_Category',
#  'Product_Name',
#  'Quantity',
#  'Unit_Price',
#  'Discount_Percent',
#  'Total_Sales',
#  'Shipping_Cost',
#  'Profit',
#  'Payment_Method']

# %% [markdown]
# # Data Dictionary
#
# | Feature | Description | Business Importance |
# |---------|-------------|---------------------|
# | Order_ID | Unique identifier for each order | Used to uniquely identify transactions |
# | Order_Date | Date when the order was placed | Used for time-series and trend analysis |
# | Customer_Name | Name of the customer | Helps identify purchasing behavior |
# | Customer_Segment | Type of customer | Used for customer segmentation |
# | Country | Customer's country | Helps compare international performance |
# | Region | Customer's region | Used for regional sales analysis |
# | Product_Category | Product category | Helps identify top-performing categories |
# | Product_Name | Name of the product | Used for product-level analysis |
# | Quantity | Number of units sold | Measures product demand |
# | Unit_Price | Price per unit | Used for revenue calculations |
# | Discount_Percent | Discount offered | Helps analyze discount impact |
# | Total_Sales | Total revenue generated | One of the primary business KPIs |
# | Shipping_Cost | Delivery cost | Used in cost analysis |
# | Profit | Profit earned from each order | Measures business profitability |
# | Payment_Method | Customer payment method | Helps understand payment preferences |

# %%
# Count numerical and categorical columns

numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
categorical_columns = df.select_dtypes(include=["object"]).columns

print("Number of Numerical Columns :", len(numerical_columns))
print("Number of Categorical Columns :", len(categorical_columns))
# Out:
# Number of Numerical Columns : 6
# Number of Categorical Columns : 9
# C:\Users\Loq\AppData\Local\Temp\ipykernel_25336\1593682480.py:4: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include=["object"]).columns

# %% [markdown]
# # Business Observation
#
# The dataset contains a balanced combination of numerical and categorical features. Numerical variables will support quantitative analysis such as sales and profit calculations, while categorical variables will help perform customer segmentation, regional analysis, and product category comparisons.

# %%
# Display numerical columns

numerical_columns
# Out:
# Index(['Quantity', 'Unit_Price', 'Discount_Percent', 'Total_Sales',
#        'Shipping_Cost', 'Profit'],
#       dtype='str')

# %%
# Display categorical columns

categorical_columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Name', 'Customer_Segment',
#        'Country', 'Region', 'Product_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='str')

# %% [markdown]
# # Business Observation
#
# The available features provide a complete business view by combining transactional, customer, product, financial, and geographical information. This makes the dataset suitable for SQL analysis, exploratory data analysis, machine learning, and business intelligence dashboard development.

# %% [markdown]
# # Initial Business Questions
#
# The following business questions will be explored during this project:
#
# 1. Which product category generates the highest sales?
# 2. Which region contributes the highest revenue?
# 3. Which customer segment generates the highest profit?
# 4. Which payment method is most frequently used?
# 5. What are the monthly sales trends?
# 6. Which products are the most profitable?
# 7. How do discounts impact profitability?
# 8. Which countries contribute the highest sales?
# 9. What are the top-performing products?
# 10. Which business metrics should be monitored through dashboards?

# %% [markdown]
# # Business Importance
#
# Answering these questions will help business stakeholders understand customer behavior, improve sales strategies, optimize inventory, increase profitability, and make informed business decisions using data.

# %% [markdown]
# # Initial Business Observations
#
# Based on the initial exploration of the dataset:
#
# - The dataset contains 2,000 retail transaction records.
# - The dataset contains 15 business-related features.
# - Both numerical and categorical variables are available.
# - The dataset structure is organized and easy to analyze.
# - The available features support descriptive, diagnostic, and predictive analytics.
# - The dataset is suitable for SQL analysis, exploratory data analysis (EDA), machine learning, and dashboard development.

# %% [markdown]
# # Conclusion
#
# The Data Understanding phase has been successfully completed.
#
# The dataset has been explored from both technical and business perspectives. Its structure, quality, and key features have been examined, providing a solid foundation for the remaining stages of the analytics lifecycle.
#
# The next phase of the project will focus on Data Cleaning, where data quality issues will be addressed and the dataset will be prepared for SQL analysis, exploratory data analysis (EDA), machine learning, and dashboard development.
